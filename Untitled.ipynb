# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# !cat result | awk -F ": " '{ if ($2 != "") print $2; else print "\n" $0 "\n------"}'
# Out:
# 5 1
# ------
# 355
# 26
# 20
# 69
#
# 5 10
# ------
# 355
# 423
# 15
# 48
#
# 5 50
# ------
# 386
# 7214
# 26
# 61
#
# 100 1
# ------
# 341
# 19
# 10
# 57
#
# 100 10
# ------
# 350
# 414
# 13
# 64
#
# 100 50
# ------
# 387
# 7404
# 11
# 79
#
# 1000 1
# ------
# 336
# 15
# 11
# 94

# %%
with open('result', 'r') as f:
    a = f.read()
    print(a)

# %%
# !cat final_data_5_1 | awk '{ if ($1 == 5) print $2}'
# Out:
# 354
# 359
# 344
# 377
# 388

# %%
plt.plot(np.arange(1, 6, 1), [367, 368, 322, 363, 359], '--', label='1')
plt.plot(np.arange(1, 6, 1), [354, 332, 349, 368, 319], '--', label='2')
plt.plot(np.arange(1, 6, 1), [358, 341, 353, 363, 331], '--', label='3')
plt.plot(np.arange(1, 6, 1), [394, 330, 373, 360, 352], '--', label='4')
plt.plot(np.arange(1, 6, 1), [354, 359, 344, 377, 388], '--', label='5')
plt.title('Приёмов пищи')
plt.ylabel('Кол-во')
plt.xlabel('Философ')
plt.legend()
plt.show()

# %%
# !cat result
# Out:
# 5 1
# count av: 355
# wait av: 26
# average diff: 20
# max diff: 69
# 5 10
# count av: 355
# wait av: 423
# average diff: 15
# max diff: 48
# 5 50
# count av: 386
# wait av: 7214
# average diff: 26
# max diff: 61
# 100 1
# count av: 341
# wait av: 19
# average diff: 10
# max diff: 57
# 100 10
# count av: 350
# wait av: 414
# average diff: 13
# max diff: 64
# 100 50
# count av: 387
# wait av: 7404
# average diff: 11
# max diff: 79
# 1000 1
# count av: 336
# wait av: 15
# average diff: 11
# max diff: 94
# 1000 10
# count av: 358
# wait av: 436
# average diff: 13
# max diff: 90
# 1000 50
# count av: 393
# wait av: 7475
# average diff: 13
# max diff: 92

# %%
plt.scatter([5, 100, 1000], [355, 341, 336],  label='timeout 1') 
plt.scatter([5, 100, 1000], [355, 350, 358],  label='timeout 10')
plt.scatter([5, 100, 1000], [386, 387, 393], label='timeout 50')
plt.title('Приёмов пищи')
plt.ylabel('count av')
plt.xlabel('количество философов')
plt.legend()
plt.show()

# %%
# !cat result_
# Out:
# 5 1
# count av: 373
# wait av: 5669
# average diff: 11
# max diff: 30
# 5 10
# count av: 392
# wait av: 6411
# average diff: 14
# max diff: 37
# 5 50
# count av: 404
# wait av: 11723
# average diff: 15
# max diff: 36
# 100 1
# count av: 384
# wait av: 6021
# average diff: 10
# max diff: 48
# 100 10
# count av: 392
# wait av: 6581
# average diff: 10
# max diff: 54
# 100 50
# count av: 399
# wait av: 11347
# average diff: 10
# max diff: 60
# 1000 1
# count av: 381
# wait av: 6009
# average diff: 12
# max diff: 73
# 1000 10
# count av: 400
# wait av: 6709
# average diff: 12
# max diff: 83
# 1000 50
# count av: 407
# wait av: 11350
# average diff: 12
# max diff: 74

# %%
# !cat fin_data_5_10
# Out:
# 1 398 6206
# 2 378 7035
# 3 398 6751
# 4 382 5929
# 5 391 5687
# 1 381 7172
# 2 418 6951
# 3 399 6215
# 4 387 6669
# 5 387 5244
# 1 410 6201
# 2 388 7181
# 3 402 6254
# 4 394 6401
# 5 376 6277

# %%
# !ls
# Out:
# create_data	    final_data_5_50		  PhilosophersTask.cs
# data		    final.exe			  result
# default_solution    first_solution		  result_
# experiment	    modern			  result_Philosophers.exe
# final.cs	    modern_			  second_solution
# final_data_1000_1   Philosophers.cs		  statistics.py
# final_data_1000_10  Philosophers.exe		  third_solution
# final_data_1000_50  Philosophers.exe_data_100_1   train.cs
# final_data_100_1    Philosophers.exe_data_100_10  train.exe
# final_data_100_10   Philosophers.exe_data_100_50  tr.cs
# final_data_100_50   Philosophers.exe_data_5_1	  tr.exe
# final_data_5_1	    Philosophers.exe_data_5_10	  Untitled.ipynb
# final_data_5_10     Philosophers.exe_data_5_50

# %%
# !cat result_Philosophers.exe
# Out:
# count av: 417
# wait av: 20519
# average diff: 52
# max diff: 113
# count av: 399
# wait av: 20402
# average diff: 47
# max diff: 113
# count av: 399
# wait av: 20190
# average diff: 49
# max diff: 110
# count av: 397
# wait av: 20397
# average diff: 51
# max diff: 110
# count av: 398
# wait av: 20472
# average diff: 52
# max diff: 113
# count av: 414
# wait av: 19671
# average diff: 46
# max diff: 102
# count av: 406
# wait av: 20335
# average diff: 50
# max diff: 108
# count av: 399
# wait av: 19572
# average diff: 43
# max diff: 95
# count av: 412
# wait av: 19433
# average diff: 48
# max diff: 102
